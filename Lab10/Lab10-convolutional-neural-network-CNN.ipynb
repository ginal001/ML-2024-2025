# %% [markdown]
# <a href="https://colab.research.google.com/github/SzymonNowakowski/Machine-Learning-2024/blob/master/Lab10-convolutional-neural-network-CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 10 - Convolutional Neural Network, CNN
#
# ### Author: Szymon Nowakowski

# %% [markdown]
# # Presentation on Convolutional Layers
# --------------------
#
# We shall start off by going through a [short presentation on convolusional layers](https://github.com/SzymonNowakowski/Machine-Learning-2024/blob/master/convolutional_layers.pdf). It is best to first download it and then go through it in a slide-show layout.

# %% [markdown]
# # Reading MNIST Dataset
# ----------------------------------

# %%
import torch
import torchvision
from matplotlib import pyplot

transform = torchvision.transforms.Compose(
    [ torchvision.transforms.ToTensor(), #Converts a PIL Image or numpy.ndarray (H x W x C) in the range [0, 255] to a torch.FloatTensor of shape (C x H x W) in the range [0.0, 1.0]
      torchvision.transforms.Normalize((0.1307), (0.3081))])

trainset = torchvision.datasets.MNIST(root='./data',
                                      train=True,
                                      download=True,
                                      transform=transform)

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=2048,
                                          shuffle=True)   #we do shuffle it to give more randomizations to training epochs

testset = torchvision.datasets.MNIST(root='./data',
                                     train=False,
                                     download=True,
                                     transform=transform)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=1,
                                         shuffle=False)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %% [markdown]
# # Tensor Sizes
# -------------------
#
# Recall:
# - Batched labels are of order one. The first (and only) index is a sample index within a batch.
# - Image batches have order 4. The first order is a batch order, but a second order has dimensionality of 1 and thus it can be indexed by 0 only.
#   - This index represents a Channel number inserted here by `ToTensor()` transformation, always 0.
#   - This singleton order should be retained because we want to use convolutional layers, which explicitly require this order. For RGB images we have 3 channels, for B&W images we have only one channel.

# %% [markdown]
# # CNN Definition
# -----------------

# %% [markdown]
# ## Task
#
# Your job now is to code the definition of the LeNet5 neural network. You can find the definition [here](https://en.wikipedia.org/wiki/LeNet#/media/File:Comparison_image_neural_networks.svg).

# %%
import torch.nn as nn
import torch.nn.functional as F

class LeNet5(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.relu = torch.nn.ReLU()
        self.conv1 = torch.nn.Conv2d(kernel_size = 5, in_channels = 1, out_channels = 6)
        self.conv2 = torch.nn.Conv2d(kernel_size = 5, in_channels = 6, out_channels = 16)
        self.conv3 = torch.nn.Conv2d(kernel_size = 4, in_channels = 16, out_channels = 120)
        self.pool = nn.AvgPool2d(kernel_size = 2, stride = 2)
        self.flatten = torch.nn.Flatten()
        self.linear1 = torch.nn.Linear(120, 84)
        self.linear2 = torch.nn.Linear(84, 10)
        self.dropout = torch.nn.Dropout(0.05)

    def forward(self, x): # B, 1, 28, 28
        x = self.relu(self.conv1(x)) # B, 6, 24, 24
        x = self.pool(x) # B, 6, 12, 12
        x = self.relu(self.conv2(x)) # B, 16, 8, 8
        x = self.pool(x)  # B, 16, 4, 4
        x = self.relu(self.conv3(x)) # B, 120, 1, 1
        x = x.squeeze(-1).squeeze(-1) #B, 120
        x = F.relu(self.linear1(x)) #B, 84
        x = self.linear2(x) #B, 84
        x = self.dropout(x)
        return x

# %% [markdown]
# # Training Loop
# ----------------------

# %%
# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Working on {device}")

net = LeNet5().to(device)
optimizer = torch.optim.Adam(net.parameters(), 0.001)   #initial and fixed learning rate of 0.001.

net.train()    #it notifies the network layers (especially batchnorm or dropout layers, which we don't use in this example) that we are doing traning
for epoch in range(16):  #  an epoch is a training run through the whole data set

    loss = 0.0
    for batch, data in enumerate(trainloader):
        batch_inputs, batch_labels = data

        batch_inputs = batch_inputs.to(device)  #explicitly moving the data to the target device
        batch_labels = batch_labels.to(device)

        optimizer.zero_grad()

        batch_outputs = net(batch_inputs)   #this line calls the forward(self, x) method of the LeNet5 object. Please note,
                                            # the nonlinear activation after the last layer is NOT applied
        loss = torch.nn.functional.cross_entropy(batch_outputs, batch_labels, reduction = "mean") #instead, nonlinear softmax is applied internally in THIS loss function
        print("epoch:", epoch, "batch:", batch, "current batch loss:", loss.item())
        loss.backward()       #this computes gradients as we have seen in previous workshops
        optimizer.step()     #but this line in fact updates our neural network.
                                ####You can experiment - comment this line and check, that the loss DOE
# Out:
# Working on cuda
# epoch: 0 batch: 0 current batch loss: 2.3093512058258057
# epoch: 0 batch: 1 current batch loss: 2.2962069511413574
# epoch: 0 batch: 2 current batch loss: 2.283376932144165
# epoch: 0 batch: 3 current batch loss: 2.276397466659546
# epoch: 0 batch: 4 current batch loss: 2.2580909729003906
# epoch: 0 batch: 5 current batch loss: 2.2383971214294434
# epoch: 0 batch: 6 current batch loss: 2.21791672706604
# epoch: 0 batch: 7 current batch loss: 2.195183038711548
# epoch: 0 batch: 8 current batch loss: 2.1622095108032227
# epoch: 0 batch: 9 current batch loss: 2.1180386543273926
# epoch: 0 batch: 10 current batch loss: 2.078862428665161
# epoch: 0 batch: 11 current batch loss: 2.0258078575134277
# epoch: 0 batch: 12 current batch loss: 1.9729729890823364
# epoch: 0 batch: 13 current batch loss: 1.9236645698547363
# epoch: 0 batch: 14 current batch loss: 1.8329235315322876
# epoch: 0 batch: 15 current batch loss: 1.7634345293045044
# epoch: 0 batch: 16 current batch loss: 1.6734395027160645
# epoch: 0 batch: 17 current batch loss: 1.5777990818023682
# epoch: 0 batch: 18 current batch loss: 1.5174919366836548
# epoch: 0 batch: 19 current batch loss: 1.419142484664917
# epoch: 0 batch: 20 current batch loss: 1.3132647275924683
# epoch: 0 batch: 21 current batch loss: 1.2532960176467896
# epoch: 0 batch: 22 current batch loss: 1.1519429683685303
# epoch: 0 batch: 23 current batch loss: 1.0618386268615723
# epoch: 0 batch: 24 current batch loss: 1.032504677772522
# epoch: 0 batch: 25 current batch loss: 0.9815343618392944
# epoch: 0 batch: 26 current batch loss: 0.9357290863990784
# epoch: 0 batch: 27 current batch loss: 0.8810678720474243
# epoch: 0 batch: 28 current batch loss: 0.8635180592536926
# epoch: 0 batch: 29 current batch loss: 0.8637223243713379
# epoch: 1 batch: 0 current batch loss: 0.8139691948890686
# epoch: 1 batch: 1 current batch loss: 0.7392970323562622
# epoch: 1 batch: 2 current batch loss: 0.7423090934753418
# epoch: 1 batch: 3 current batch loss: 0.7506624460220337
# epoch: 1 batch: 4 current batch loss: 0.7404022812843323
# epoch: 1 batch: 5 current batch loss: 0.6847466826438904
# epoch: 1 batch: 6 current batch loss: 0.6713907718658447
# epoch: 1 batch: 7 current batch loss: 0.6193377375602722
# epoch: 1 batch: 8 current batch loss: 0.6581478118896484
# epoch: 1 batch: 9 current batch loss: 0.6115303039550781
# epoch: 1 batch: 10 current batch loss: 0.6473473906517029
# epoch: 1 batch: 11 current batch loss: 0.561581552028656
# epoch: 1 batch: 12 current batch loss: 0.5984424352645874
# epoch: 1 batch: 13 current batch loss: 0.6164958477020264
# epoch: 1 batch: 14 current batch loss: 0.6165223121643066
# epoch: 1 batch: 15 current batch loss: 0.5784938335418701
# epoch: 1 batch: 16 current batch loss: 0.5908022522926331
# epoch: 1 batch: 17 current batch loss: 0.57766193151474
# epoch: 1 batch: 18 current batch loss: 0.5481266975402832
# epoch: 1 batch: 19 current batch loss: 0.5660396814346313
# epoch: 1 batch: 20 current batch loss: 0.5322550535202026
# epoch: 1 batch: 21 current batch loss: 0.5424050092697144
# epoch: 1 batch: 22 current batch loss: 0.49881210923194885
# epoch: 1 batch: 23 current batch loss: 0.5554938912391663
# epoch: 1 batch: 24 current batch loss: 0.5384678244590759
# epoch: 1 batch: 25 current batch loss: 0.5262847542762756
# epoch: 1 batch: 26 current batch loss: 0.47393742203712463
# epoch: 1 batch: 27 current batch loss: 0.48174718022346497
# epoch: 1 batch: 28 current batch loss: 0.456963449716568
# epoch: 1 batch: 29 current batch loss: 0.5114668011665344
# epoch: 2 batch: 0 current batch loss: 0.4852561950683594
# epoch: 2 batch: 1 current batch loss: 0.4960259199142456
# epoch: 2 batch: 2 current batch loss: 0.45013031363487244
# epoch: 2 batch: 3 current batch loss: 0.453978955745697
# epoch: 2 batch: 4 current batch loss: 0.414192259311676
# epoch: 2 batch: 5 current batch loss: 0.46891576051712036
# epoch: 2 batch: 6 current batch loss: 0.46750500798225403
# epoch: 2 batch: 7 current batch loss: 0.4829360544681549
# epoch: 2 batch: 8 current batch loss: 0.43442338705062866
# epoch: 2 batch: 9 current batch loss: 0.44426074624061584
# epoch: 2 batch: 10 current batch loss: 0.41533195972442627
# epoch: 2 batch: 11 current batch loss: 0.4255942404270172
# epoch: 2 batch: 12 current batch loss: 0.4636518359184265
# epoch: 2 batch: 13 current batch loss: 0.4564642310142517
# epoch: 2 batch: 14 current batch loss: 0.43613743782043457
# epoch: 2 batch: 15 current batch loss: 0.39893823862075806
# epoch: 2 batch: 16 current batch loss: 0.4224027991294861
# epoch: 2 batch: 17 current batch loss: 0.41754409670829773
# epoch: 2 batch: 18 current batch loss: 0.42346689105033875
# epoch: 2 batch: 19 current batch loss: 0.39468804001808167
# epoch: 2 batch: 20 current batch loss: 0.389655202627182
# epoch: 2 batch: 21 current batch loss: 0.4159294068813324
# epoch: 2 batch: 22 current batch loss: 0.4035569429397583
# epoch: 2 batch: 23 current batch loss: 0.3977767825126648
# epoch: 2 batch: 24 current batch loss: 0.364081472158432
# epoch: 2 batch: 25 current batch loss: 0.3747935891151428
# epoch: 2 batch: 26 current batch loss: 0.3800521790981293
# epoch: 2 batch: 27 current batch loss: 0.38171443343162537
# epoch: 2 batch: 28 current batch loss: 0.3943965435028076
# epoch: 2 batch: 29 current batch loss: 0.3997732400894165
# epoch: 3 batch: 0 current batch loss: 0.3738170862197876
# epoch: 3 batch: 1 current batch loss: 0.3705461621284485
# epoch: 3 batch: 2 current batch loss: 0.35949355363845825
# epoch: 3 batch: 3 current batch loss: 0.37158793210983276
# epoch: 3 batch: 4 current batch loss: 0.4147808849811554
# epoch: 3 batch: 5 current batch loss: 0.3461255133152008
# epoch: 3 batch: 6 current batch loss: 0.3433084487915039
# epoch: 3 batch: 7 current batch loss: 0.34186211228370667
# epoch: 3 batch: 8 current batch loss: 0.4027169346809387
# epoch: 3 batch: 9 current batch loss: 0.3317038416862488
# epoch: 3 batch: 10 current batch loss: 0.36002713441848755
# epoch: 3 batch: 11 current batch loss: 0.35103052854537964
# epoch: 3 batch: 12 current batch loss: 0.35039910674095154
# epoch: 3 batch: 13 current batch loss: 0.3546987473964691
# epoch: 3 batch: 14 current batch loss: 0.33673080801963806
# epoch: 3 batch: 15 current batch loss: 0.29939213395118713
# epoch: 3 batch: 16 current batch loss: 0.3340038061141968
# epoch: 3 batch: 17 current batch loss: 0.33620843291282654
# epoch: 3 batch: 18 current batch loss: 0.36032024025917053
# epoch: 3 batch: 19 current batch loss: 0.33059751987457275
# epoch: 3 batch: 20 current batch loss: 0.3581046164035797
# epoch: 3 batch: 21 current batch loss: 0.3074013292789459
# epoch: 3 batch: 22 current batch loss: 0.3111002445220947
# epoch: 3 batch: 23 current batch loss: 0.28184568881988525
# epoch: 3 batch: 24 current batch loss: 0.288394570350647
# epoch: 3 batch: 25 current batch loss: 0.3090054988861084
# epoch: 3 batch: 26 current batch loss: 0.32409974932670593
# epoch: 3 batch: 27 current batch loss: 0.3133459687232971
# epoch: 3 batch: 28 current batch loss: 0.3022305369377136
# epoch: 3 batch: 29 current batch loss: 0.28122401237487793
# epoch: 4 batch: 0 current batch loss: 0.28531739115715027
# epoch: 4 batch: 1 current batch loss: 0.3034299612045288
# epoch: 4 batch: 2 current batch loss: 0.33319374918937683
# epoch: 4 batch: 3 current batch loss: 0.2563692331314087
# epoch: 4 batch: 4 current batch loss: 0.28277117013931274
# epoch: 4 batch: 5 current batch loss: 0.3147392272949219
# epoch: 4 batch: 6 current batch loss: 0.3067501485347748
# epoch: 4 batch: 7 current batch loss: 0.2843356132507324
# epoch: 4 batch: 8 current batch loss: 0.2720872759819031
# epoch: 4 batch: 9 current batch loss: 0.29777801036834717
# epoch: 4 batch: 10 current batch loss: 0.2671170234680176
# epoch: 4 batch: 11 current batch loss: 0.2716190814971924
# epoch: 4 batch: 12 current batch loss: 0.306146502494812
# epoch: 4 batch: 13 current batch loss: 0.2594911456108093
# epoch: 4 batch: 14 current batch loss: 0.2665422856807709
# epoch: 4 batch: 15 current batch loss: 0.27794426679611206
# epoch: 4 batch: 16 current batch loss: 0.263187974691391
# epoch: 4 batch: 17 current batch loss: 0.2687796652317047
# epoch: 4 batch: 18 current batch loss: 0.288112998008728
# epoch: 4 batch: 19 current batch loss: 0.2505815327167511
# epoch: 4 batch: 20 current batch loss: 0.25687888264656067
# epoch: 4 batch: 21 current batch loss: 0.2611381411552429
# epoch: 4 batch: 22 current batch loss: 0.2771087884902954
# epoch: 4 batch: 23 current batch loss: 0.24554263055324554
# epoch: 4 batch: 24 current batch loss: 0.26151445508003235
# epoch: 4 batch: 25 current batch loss: 0.2585991621017456
# epoch: 4 batch: 26 current batch loss: 0.22218383848667145
# epoch: 4 batch: 27 current batch loss: 0.259806752204895
# epoch: 4 batch: 28 current batch loss: 0.2623921036720276
# epoch: 4 batch: 29 current batch loss: 0.2613728940486908
# epoch: 5 batch: 0 current batch loss: 0.23950985074043274
# epoch: 5 batch: 1 current batch loss: 0.24492087960243225
# epoch: 5 batch: 2 current batch loss: 0.2650115489959717
# epoch: 5 batch: 3 current batch loss: 0.235822394490242
# epoch: 5 batch: 4 current batch loss: 0.24553048610687256
# epoch: 5 batch: 5 current batch loss: 0.2418086975812912
# epoch: 5 batch: 6 current batch loss: 0.22253702580928802
# epoch: 5 batch: 7 current batch loss: 0.27495041489601135
# epoch: 5 batch: 8 current batch loss: 0.21062889695167542
# epoch: 5 batch: 9 current batch loss: 0.23216676712036133
# epoch: 5 batch: 10 current batch loss: 0.22608868777751923
# epoch: 5 batch: 11 current batch loss: 0.22029873728752136
# epoch: 5 batch: 12 current batch loss: 0.2269241213798523
# epoch: 5 batch: 13 current batch loss: 0.22166629135608673
# epoch: 5 batch: 14 current batch loss: 0.22627019882202148
# epoch: 5 batch: 15 current batch loss: 0.2257125824689865
# epoch: 5 batch: 16 current batch loss: 0.19502855837345123
# epoch: 5 batch: 17 current batch loss: 0.22762738168239594
# epoch: 5 batch: 18 current batch loss: 0.2050417959690094
# epoch: 5 batch: 19 current batch loss: 0.21584072709083557
# epoch: 5 batch: 20 current batch loss: 0.24576875567436218
# epoch: 5 batch: 21 current batch loss: 0.22590672969818115
# epoch: 5 batch: 22 current batch loss: 0.21893273293972015
# epoch: 5 batch: 23 current batch loss: 0.21429428458213806
# epoch: 5 batch: 24 current batch loss: 0.22168532013893127
# epoch: 5 batch: 25 current batch loss: 0.20604175329208374
# epoch: 5 batch: 26 current batch loss: 0.20655018091201782
# epoch: 5 batch: 27 current batch loss: 0.20616655051708221
# epoch: 5 batch: 28 current batch loss: 0.19801834225654602
# epoch: 5 batch: 29 current batch loss: 0.19588543474674225
# epoch: 6 batch: 0 current batch loss: 0.19846630096435547
# epoch: 6 batch: 1 current batch loss: 0.16672194004058838
# epoch: 6 batch: 2 current batch loss: 0.19677001237869263
# epoch: 6 batch: 3 current batch loss: 0.19379688799381256
# epoch: 6 batch: 4 current batch loss: 0.20769333839416504
# epoch: 6 batch: 5 current batch loss: 0.19427527487277985
# epoch: 6 batch: 6 current batch loss: 0.2008408159017563
# epoch: 6 batch: 7 current batch loss: 0.21112056076526642
# epoch: 6 batch: 8 current batch loss: 0.2014295607805252
# epoch: 6 batch: 9 current batch loss: 0.20263777673244476
# epoch: 6 batch: 10 current batch loss: 0.2131270468235016
# epoch: 6 batch: 11 current batch loss: 0.18631786108016968
# epoch: 6 batch: 12 current batch loss: 0.20525532960891724
# epoch: 6 batch: 13 current batch loss: 0.2066502720117569
# epoch: 6 batch: 14 current batch loss: 0.19487138092517853
# epoch: 6 batch: 15 current batch loss: 0.22511492669582367
# epoch: 6 batch: 16 current batch loss: 0.18588992953300476
# epoch: 6 batch: 17 current batch loss: 0.20337393879890442
# epoch: 6 batch: 18 current batch loss: 0.21107889711856842
# epoch: 6 batch: 19 current batch loss: 0.16056901216506958
# epoch: 6 batch: 20 current batch loss: 0.18589302897453308
# epoch: 6 batch: 21 current batch loss: 0.19287575781345367
# epoch: 6 batch: 22 current batch loss: 0.20941641926765442
# epoch: 6 batch: 23 current batch loss: 0.15272553265094757
# epoch: 6 batch: 24 current batch loss: 0.16325464844703674
# epoch: 6 batch: 25 current batch loss: 0.18628425896167755
# epoch: 6 batch: 26 current batch loss: 0.15154752135276794
# epoch: 6 batch: 27 current batch loss: 0.164446622133255
# epoch: 6 batch: 28 current batch loss: 0.15626366436481476
# epoch: 6 batch: 29 current batch loss: 0.2096182405948639
# epoch: 7 batch: 0 current batch loss: 0.18463867902755737
# epoch: 7 batch: 1 current batch loss: 0.17066946625709534
# epoch: 7 batch: 2 current batch loss: 0.1540696918964386
# epoch: 7 batch: 3 current batch loss: 0.19271060824394226
# epoch: 7 batch: 4 current batch loss: 0.16717477142810822
# epoch: 7 batch: 5 current batch loss: 0.16635800898075104
# epoch: 7 batch: 6 current batch loss: 0.1566508412361145
# epoch: 7 batch: 7 current batch loss: 0.17476999759674072
# epoch: 7 batch: 8 current batch loss: 0.17332963645458221
# epoch: 7 batch: 9 current batch loss: 0.17693465948104858
# epoch: 7 batch: 10 current batch loss: 0.16442328691482544
# epoch: 7 batch: 11 current batch loss: 0.1711849421262741
# epoch: 7 batch: 12 current batch loss: 0.16146832704544067
# epoch: 7 batch: 13 current batch loss: 0.16186033189296722
# epoch: 7 batch: 14 current batch loss: 0.1662941426038742
# epoch: 7 batch: 15 current batch loss: 0.1815381795167923
# epoch: 7 batch: 16 current batch loss: 0.16185836493968964
# epoch: 7 batch: 17 current batch loss: 0.15781566500663757
# epoch: 7 batch: 18 current batch loss: 0.14172405004501343
# epoch: 7 batch: 19 current batch loss: 0.1655677706003189
# epoch: 7 batch: 20 current batch loss: 0.15854865312576294
# epoch: 7 batch: 21 current batch loss: 0.16984327137470245
# epoch: 7 batch: 22 current batch loss: 0.15504127740859985
# epoch: 7 batch: 23 current batch loss: 0.17639727890491486
# epoch: 7 batch: 24 current batch loss: 0.18046881258487701
# epoch: 7 batch: 25 current batch loss: 0.1500471830368042
# epoch: 7 batch: 26 current batch loss: 0.16218876838684082
# epoch: 7 batch: 27 current batch loss: 0.16787678003311157
# epoch: 7 batch: 28 current batch loss: 0.1633240431547165
# epoch: 7 batch: 29 current batch loss: 0.20454958081245422
# epoch: 8 batch: 0 current batch loss: 0.14811691641807556
# epoch: 8 batch: 1 current batch loss: 0.16896583139896393
# epoch: 8 batch: 2 current batch loss: 0.16478587687015533
# epoch: 8 batch: 3 current batch loss: 0.14499206840991974
# epoch: 8 batch: 4 current batch loss: 0.13842760026454926
# epoch: 8 batch: 5 current batch loss: 0.14667561650276184
# epoch: 8 batch: 6 current batch loss: 0.13172203302383423
# epoch: 8 batch: 7 current batch loss: 0.13954125344753265
# epoch: 8 batch: 8 current batch loss: 0.16811563074588776
# epoch: 8 batch: 9 current batch loss: 0.1608094722032547
# epoch: 8 batch: 10 current batch loss: 0.1502220332622528
# epoch: 8 batch: 11 current batch loss: 0.15664386749267578
# epoch: 8 batch: 12 current batch loss: 0.16240081191062927
# epoch: 8 batch: 13 current batch loss: 0.1451214998960495
# epoch: 8 batch: 14 current batch loss: 0.1439376026391983
# epoch: 8 batch: 15 current batch loss: 0.1494869589805603
# epoch: 8 batch: 16 current batch loss: 0.15087585151195526
# epoch: 8 batch: 17 current batch loss: 0.1432734727859497
# epoch: 8 batch: 18 current batch loss: 0.1463497132062912
# epoch: 8 batch: 19 current batch loss: 0.14463819563388824
# epoch: 8 batch: 20 current batch loss: 0.14654456079006195
# epoch: 8 batch: 21 current batch loss: 0.14414432644844055
# epoch: 8 batch: 22 current batch loss: 0.16624517738819122
# epoch: 8 batch: 23 current batch loss: 0.15795066952705383
# epoch: 8 batch: 24 current batch loss: 0.14882473647594452
# epoch: 8 batch: 25 current batch loss: 0.1824135184288025
# epoch: 8 batch: 26 current batch loss: 0.14310824871063232
# epoch: 8 batch: 27 current batch loss: 0.17404435575008392
# epoch: 8 batch: 28 current batch loss: 0.14314132928848267
# epoch: 8 batch: 29 current batch loss: 0.14962558448314667
# epoch: 9 batch: 0 current batch loss: 0.12890857458114624
# epoch: 9 batch: 1 current batch loss: 0.1421484649181366
# epoch: 9 batch: 2 current batch loss: 0.1583322137594223
# epoch: 9 batch: 3 current batch loss: 0.12746809422969818
# epoch: 9 batch: 4 current batch loss: 0.1437148153781891
# epoch: 9 batch: 5 current batch loss: 0.12765243649482727
# epoch: 9 batch: 6 current batch loss: 0.1535487025976181
# epoch: 9 batch: 7 current batch loss: 0.14508351683616638
# epoch: 9 batch: 8 current batch loss: 0.1302788108587265
# epoch: 9 batch: 9 current batch loss: 0.14254912734031677
# epoch: 9 batch: 10 current batch loss: 0.13976919651031494
# epoch: 9 batch: 11 current batch loss: 0.1295592486858368
# epoch: 9 batch: 12 current batch loss: 0.11685787886381149
# epoch: 9 batch: 13 current batch loss: 0.12686417996883392
# epoch: 9 batch: 14 current batch loss: 0.14561505615711212
# epoch: 9 batch: 15 current batch loss: 0.1144801452755928
# epoch: 9 batch: 16 current batch loss: 0.13388347625732422
# epoch: 9 batch: 17 current batch loss: 0.13302722573280334
# epoch: 9 batch: 18 current batch loss: 0.12486489862203598
# epoch: 9 batch: 19 current batch loss: 0.15323616564273834
# epoch: 9 batch: 20 current batch loss: 0.1521752029657364
# epoch: 9 batch: 21 current batch loss: 0.14146828651428223
# epoch: 9 batch: 22 current batch loss: 0.1385190486907959
# epoch: 9 batch: 23 current batch loss: 0.12251032143831253
# epoch: 9 batch: 24 current batch loss: 0.1292313039302826
# epoch: 9 batch: 25 current batch loss: 0.1487485021352768
# epoch: 9 batch: 26 current batch loss: 0.14632073044776917
# epoch: 9 batch: 27 current batch loss: 0.13142970204353333
# epoch: 9 batch: 28 current batch loss: 0.1475106030702591
# epoch: 9 batch: 29 current batch loss: 0.15083841979503632
# epoch: 10 batch: 0 current batch loss: 0.15463320910930634
# epoch: 10 batch: 1 current batch loss: 0.13496674597263336
# epoch: 10 batch: 2 current batch loss: 0.12955297529697418
# epoch: 10 batch: 3 current batch loss: 0.13863368332386017
# epoch: 10 batch: 4 current batch loss: 0.14700119197368622
# epoch: 10 batch: 5 current batch loss: 0.12529630959033966
# epoch: 10 batch: 6 current batch loss: 0.12470802664756775
# epoch: 10 batch: 7 current batch loss: 0.12269268184900284
# epoch: 10 batch: 8 current batch loss: 0.12523747980594635
# epoch: 10 batch: 9 current batch loss: 0.11362714320421219
# epoch: 10 batch: 10 current batch loss: 0.1321430802345276
# epoch: 10 batch: 11 current batch loss: 0.11833522468805313
# epoch: 10 batch: 12 current batch loss: 0.131940558552742
# epoch: 10 batch: 13 current batch loss: 0.13308851420879364
# epoch: 10 batch: 14 current batch loss: 0.13418403267860413
# epoch: 10 batch: 15 current batch loss: 0.1179419606924057
# epoch: 10 batch: 16 current batch loss: 0.10495351254940033
# epoch: 10 batch: 17 current batch loss: 0.11982136964797974
# epoch: 10 batch: 18 current batch loss: 0.12146083265542984
# epoch: 10 batch: 19 current batch loss: 0.12369444966316223
# epoch: 10 batch: 20 current batch loss: 0.12229298055171967
# epoch: 10 batch: 21 current batch loss: 0.1226268857717514
# epoch: 10 batch: 22 current batch loss: 0.11482390761375427
# epoch: 10 batch: 23 current batch loss: 0.11866891384124756
# epoch: 10 batch: 24 current batch loss: 0.1255997270345688
# epoch: 10 batch: 25 current batch loss: 0.11651794612407684
# epoch: 10 batch: 26 current batch loss: 0.1142367273569107
# epoch: 10 batch: 27 current batch loss: 0.11877884715795517
# epoch: 10 batch: 28 current batch loss: 0.12343566864728928
# epoch: 10 batch: 29 current batch loss: 0.08411058038473129
# epoch: 11 batch: 0 current batch loss: 0.09824080020189285
# epoch: 11 batch: 1 current batch loss: 0.13706357777118683
# epoch: 11 batch: 2 current batch loss: 0.11123199015855789
# epoch: 11 batch: 3 current batch loss: 0.1201314628124237
# epoch: 11 batch: 4 current batch loss: 0.11705920845270157
# epoch: 11 batch: 5 current batch loss: 0.11737289279699326
# epoch: 11 batch: 6 current batch loss: 0.12877503037452698
# epoch: 11 batch: 7 current batch loss: 0.12456123530864716
# epoch: 11 batch: 8 current batch loss: 0.1128058210015297
# epoch: 11 batch: 9 current batch loss: 0.12419480830430984
# epoch: 11 batch: 10 current batch loss: 0.14086362719535828
# epoch: 11 batch: 11 current batch loss: 0.10908441245555878
# epoch: 11 batch: 12 current batch loss: 0.10925628244876862
# epoch: 11 batch: 13 current batch loss: 0.11627047508955002
# epoch: 11 batch: 14 current batch loss: 0.09649571776390076
# epoch: 11 batch: 15 current batch loss: 0.1083521693944931
# epoch: 11 batch: 16 current batch loss: 0.10389317572116852
# epoch: 11 batch: 17 current batch loss: 0.11428076773881912
# epoch: 11 batch: 18 current batch loss: 0.1118718609213829
# epoch: 11 batch: 19 current batch loss: 0.11408038437366486
# epoch: 11 batch: 20 current batch loss: 0.12123475968837738
# epoch: 11 batch: 21 current batch loss: 0.10107263177633286
# epoch: 11 batch: 22 current batch loss: 0.10870891064405441
# epoch: 11 batch: 23 current batch loss: 0.11798212677240372
# epoch: 11 batch: 24 current batch loss: 0.12688760459423065
# epoch: 11 batch: 25 current batch loss: 0.12828978896141052
# epoch: 11 batch: 26 current batch loss: 0.12995588779449463
# epoch: 11 batch: 27 current batch loss: 0.12348726391792297
# epoch: 11 batch: 28 current batch loss: 0.12363549321889877
# epoch: 11 batch: 29 current batch loss: 0.1143147200345993
# epoch: 12 batch: 0 current batch loss: 0.10568199306726456
# epoch: 12 batch: 1 current batch loss: 0.11015968024730682
# epoch: 12 batch: 2 current batch loss: 0.11342357099056244
# epoch: 12 batch: 3 current batch loss: 0.11518040299415588
# epoch: 12 batch: 4 current batch loss: 0.10305581986904144
# epoch: 12 batch: 5 current batch loss: 0.13132581114768982
# epoch: 12 batch: 6 current batch loss: 0.1271025538444519
# epoch: 12 batch: 7 current batch loss: 0.10853296518325806
# epoch: 12 batch: 8 current batch loss: 0.10966689139604568
# epoch: 12 batch: 9 current batch loss: 0.10710904002189636
# epoch: 12 batch: 10 current batch loss: 0.10778958350419998
# epoch: 12 batch: 11 current batch loss: 0.11182860285043716
# epoch: 12 batch: 12 current batch loss: 0.08829475939273834
# epoch: 12 batch: 13 current batch loss: 0.10684448480606079
# epoch: 12 batch: 14 current batch loss: 0.10176477581262589
# epoch: 12 batch: 15 current batch loss: 0.09756280481815338
# epoch: 12 batch: 16 current batch loss: 0.127656489610672
# epoch: 12 batch: 17 current batch loss: 0.11058066785335541
# epoch: 12 batch: 18 current batch loss: 0.12846258282661438
# epoch: 12 batch: 19 current batch loss: 0.08206339180469513
# epoch: 12 batch: 20 current batch loss: 0.10994403064250946
# epoch: 12 batch: 21 current batch loss: 0.10692587494850159
# epoch: 12 batch: 22 current batch loss: 0.10694306343793869
# epoch: 12 batch: 23 current batch loss: 0.11848048865795135
# epoch: 12 batch: 24 current batch loss: 0.12055344879627228
# epoch: 12 batch: 25 current batch loss: 0.1253739893436432
# epoch: 12 batch: 26 current batch loss: 0.12516248226165771
# epoch: 12 batch: 27 current batch loss: 0.09989258646965027
# epoch: 12 batch: 28 current batch loss: 0.09733568876981735
# epoch: 12 batch: 29 current batch loss: 0.1309695690870285
# epoch: 13 batch: 0 current batch loss: 0.09545193612575531
# epoch: 13 batch: 1 current batch loss: 0.11880917847156525
# epoch: 13 batch: 2 current batch loss: 0.10051637142896652
# epoch: 13 batch: 3 current batch loss: 0.12007759511470795
# epoch: 13 batch: 4 current batch loss: 0.1142524927854538
# epoch: 13 batch: 5 current batch loss: 0.08846680819988251
# epoch: 13 batch: 6 current batch loss: 0.11685491353273392
# epoch: 13 batch: 7 current batch loss: 0.11323689669370651
# epoch: 13 batch: 8 current batch loss: 0.1141139343380928
# epoch: 13 batch: 9 current batch loss: 0.10893122106790543
# epoch: 13 batch: 10 current batch loss: 0.11048022657632828
# epoch: 13 batch: 11 current batch loss: 0.10428216308355331
# epoch: 13 batch: 12 current batch loss: 0.10773777216672897
# epoch: 13 batch: 13 current batch loss: 0.09834443032741547
# epoch: 13 batch: 14 current batch loss: 0.08283290266990662
# epoch: 13 batch: 15 current batch loss: 0.11453654617071152
# epoch: 13 batch: 16 current batch loss: 0.09492233395576477
# epoch: 13 batch: 17 current batch loss: 0.08814330399036407
# epoch: 13 batch: 18 current batch loss: 0.11633175611495972
# epoch: 13 batch: 19 current batch loss: 0.09134376794099808
# epoch: 13 batch: 20 current batch loss: 0.11830363422632217
# epoch: 13 batch: 21 current batch loss: 0.10120968520641327
# epoch: 13 batch: 22 current batch loss: 0.10645563155412674
# epoch: 13 batch: 23 current batch loss: 0.10250489413738251
# epoch: 13 batch: 24 current batch loss: 0.11625409126281738
# epoch: 13 batch: 25 current batch loss: 0.0921943187713623
# epoch: 13 batch: 26 current batch loss: 0.10398372262716293
# epoch: 13 batch: 27 current batch loss: 0.10919427126646042
# epoch: 13 batch: 28 current batch loss: 0.09393007308244705
# epoch: 13 batch: 29 current batch loss: 0.1104312539100647
# epoch: 14 batch: 0 current batch loss: 0.10156478732824326
# epoch: 14 batch: 1 current batch loss: 0.08943834900856018
# epoch: 14 batch: 2 current batch loss: 0.1007094606757164
# epoch: 14 batch: 3 current batch loss: 0.1111467033624649
# epoch: 14 batch: 4 current batch loss: 0.10598015040159225
# epoch: 14 batch: 5 current batch loss: 0.10103809088468552
# epoch: 14 batch: 6 current batch loss: 0.08952126652002335
# epoch: 14 batch: 7 current batch loss: 0.10031598061323166
# epoch: 14 batch: 8 current batch loss: 0.10572018474340439
# epoch: 14 batch: 9 current batch loss: 0.10453040897846222
# epoch: 14 batch: 10 current batch loss: 0.10073405504226685
# epoch: 14 batch: 11 current batch loss: 0.10095546394586563
# epoch: 14 batch: 12 current batch loss: 0.09621235728263855
# epoch: 14 batch: 13 current batch loss: 0.09299692511558533
# epoch: 14 batch: 14 current batch loss: 0.10124179720878601
# epoch: 14 batch: 15 current batch loss: 0.10607225447893143
# epoch: 14 batch: 16 current batch loss: 0.10980942845344543
# epoch: 14 batch: 17 current batch loss: 0.09808892011642456
# epoch: 14 batch: 18 current batch loss: 0.09415877610445023
# epoch: 14 batch: 19 current batch loss: 0.10415345430374146
# epoch: 14 batch: 20 current batch loss: 0.09466153383255005
# epoch: 14 batch: 21 current batch loss: 0.10311734676361084
# epoch: 14 batch: 22 current batch loss: 0.10164181143045425
# epoch: 14 batch: 23 current batch loss: 0.11279909312725067
# epoch: 14 batch: 24 current batch loss: 0.09341469407081604
# epoch: 14 batch: 25 current batch loss: 0.09957194328308105
# epoch: 14 batch: 26 current batch loss: 0.09090136736631393
# epoch: 14 batch: 27 current batch loss: 0.09821948409080505
# epoch: 14 batch: 28 current batch loss: 0.09954571723937988
# epoch: 14 batch: 29 current batch loss: 0.08971133083105087
# epoch: 15 batch: 0 current batch loss: 0.09113675355911255
# epoch: 15 batch: 1 current batch loss: 0.09405815601348877
# epoch: 15 batch: 2 current batch loss: 0.1033201813697815
# epoch: 15 batch: 3 current batch loss: 0.08387009799480438
# epoch: 15 batch: 4 current batch loss: 0.0876004621386528
# epoch: 15 batch: 5 current batch loss: 0.08647266775369644
# epoch: 15 batch: 6 current batch loss: 0.09539373964071274
# epoch: 15 batch: 7 current batch loss: 0.08498170226812363
# epoch: 15 batch: 8 current batch loss: 0.1024852767586708
# epoch: 15 batch: 9 current batch loss: 0.11414927244186401
# epoch: 15 batch: 10 current batch loss: 0.08647970855236053
# epoch: 15 batch: 11 current batch loss: 0.10077765583992004
# epoch: 15 batch: 12 current batch loss: 0.09805575758218765
# epoch: 15 batch: 13 current batch loss: 0.09624236077070236
# epoch: 15 batch: 14 current batch loss: 0.09350871294736862
# epoch: 15 batch: 15 current batch loss: 0.08623888343572617
# epoch: 15 batch: 16 current batch loss: 0.08975569903850555
# epoch: 15 batch: 17 current batch loss: 0.09130056947469711
# epoch: 15 batch: 18 current batch loss: 0.08088941872119904
# epoch: 15 batch: 19 current batch loss: 0.09932021796703339
# epoch: 15 batch: 20 current batch loss: 0.08978433907032013
# epoch: 15 batch: 21 current batch loss: 0.0936792865395546
# epoch: 15 batch: 22 current batch loss: 0.11756166070699692
# epoch: 15 batch: 23 current batch loss: 0.09987544268369675
# epoch: 15 batch: 24 current batch loss: 0.12092223763465881
# epoch: 15 batch: 25 current batch loss: 0.09275563061237335
# epoch: 15 batch: 26 current batch loss: 0.08815274387598038
# epoch: 15 batch: 27 current batch loss: 0.09663031250238419
# epoch: 15 batch: 28 current batch loss: 0.09389594942331314
# epoch: 15 batch: 29 current batch loss: 0.06177631765604019

# %% [markdown]
# # Testing
# ----------------------

# %%
good = 0
wrong = 0

net.eval()              #it notifies the network layers (especially batchnorm or dropout layers, which we don't use in this example) that we are doing evaluation
with torch.no_grad():   #it prevents that the net learns during evalution. The gradients are not computed, so this makes it faster, too
    for batch, data in enumerate(testloader): #batches in test are of size 1
        datapoint, label = data

        prediction = net(datapoint.to(device))                  #prediction has values representing the "prevalence" of the corresponding class
        classification = torch.argmax(prediction)    #the class is the index of maximal "prevalence"

        if classification.item() == label.item():
            good += 1
        else:
            wrong += 1

print("accuracy = ", good/(good+wrong))
# Out:
# accuracy =  0.9778

# %% [markdown]
# # Understanding Kernel Size, Stride and Padding

# %% [markdown]
# ## Task: Designing a Convolutional Neural Network with a Target Receptive Field
#
# Design a convolutional neural network using only 3×3 or 5×5 convolutional layers and 2×2 max-pooling layers without overlap (i.e., with stride 2). Use no padding in any layer. Insert a max-pooling layer after every two or three convolutional layers.
#
# Your goal is to construct an architecture such that the receptive field of each output neuron is approximately 60×60 pixels.
#
# Compute the receptive field size of the final output layer.
#
# Compute the effective stride of the output layer with respect to the input.
#
# Assuming an input image size of 400×400, determine the spatial size of the output feature map.
#
# Q: Where would you locate ReLU layers?
# Q: What if we can't match the desired input size with our architecture?
# Q: Discuss what possible impact padding can have on the network performance.

# %% [markdown]
# # **Homework Assignment – Adversarial Examples**
#
# In this assignment, you will explore how small (invisible to humans) changes to real digits can _fool_ the CNN into misclassifying them, even though the changes are imperceptible to humans.
#
#
#
# ## Task 1 – CNN Dreams: Last Homework Assignment Revisited
#
# Re-run the input optimization process (for NN dreams) from the previous MLP-class homework assignment, but this time using the **LeNet-5 CNN model** we trained in this class.
#
#
# 1. Starting from ten random noise images, optimize the input so that each image is classified with high confidence as one of the digits 0 through 9.
# 2. Include an **L2 penalty** on the input to keep the images visually closer to realistic digits. Use a range of penalty strengths (e.g., $\lambda_{l2}$ = 0, and then 0.01 through 10.0).
# 3. Compare the generated images (with and without L2 penalty) to those generated by the MLP:
#    - Are they more or less readable?
#    - Do they resemble real MNIST digits more closely or less?
#    - Why do you think that happens? Consider the CNN’s inductive biases and architectural properties.
#
# Use `cross_entropy_loss + lambda_l2 * input.pow(2).mean()` as your objective.
#
# Reuse your code: visualize confidence evolution during optimization and generate image grids and (optionally) animations showing how the inputs evolve.
#
#
# ## Task 2 – Adversarial Examples: Fooling LeNet-5
#
# This is the core focus of the assignment.
#
# Using a batch of **real MNIST digits** (e.g., nine examples per class), craft **adversarial examples** by adding subtle, trained noise to the input images. Your goal is to:
#
# - **Keep the human-perceived digit the same** (e.g., a "7" should still look like a "7"),
# - But **cause LeNet-5 to misclassify it** – as every other class different from the original, hence nine examples per class.
#
# ### Objective
# For each image $x$ and its true label $y$, learn a perturbation $\delta$ such that:
#
# - $\text{LeNet5}(x + \delta) = y_{\text{wrong}} $,
# - and $ \|\delta\|_2 $ is as small as possible (penalize large perturbations), to keep $x + \delta$ *look* like $x$ for humans.
#
# ### Optimization
# Use gradient-based optimization on $\delta$ (the noise), while keeping the network weights frozen. Your loss might look like:
#
# ```
# loss = cross_entropy(model(x + delta), target_wrong_class) +
#        lambda_l2 * delta.pow(2).mean()
# ```
#
# Tune the $\lambda_{l2}$ to find the best range.
#
# ### Deliverables for the Second Task
# - Select some best examples, showing the original digit and its (correct) classification and the perturbed digit (hopefully, still looking the same to humans) and how it gets misclassified. Show them side by side.
# - Report:
#   - Success rate of attacks (it doesn't need to be very formal),
#   - Effect of $\lambda_{l2}$ on visibility of the noise and success of misclassification,
#   - Example image grids and confidence plots.
#
#
#
# ## Deliverables for the Homework Assignment
# - A Google Colab notebook with:
#   - Complete implementation for both tasks.
#   - Visualizations and animations (animations are optional but encouraged).
#   - Clear written analysis of your findings.
# - Upload the notebook and results to your GitHub repository for the course.
# - Include a link to the notebook and video (if applicable) in the `README.md`.
# - In the notebook, include “Open in Colab” badge so it can be launched directly.
